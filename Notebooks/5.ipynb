# %% [markdown]
# # Soal 5
# Diketahui bilangan acak (random variable) berdistribusi exponential (λ = 3). Tentukan

# %% [markdown]
# - a. Fungsi Probabilitas dari Distribusi Exponensial

# %%
m <- 3
set.seed(1)
p <- dexp(rexp(1, rate = m), rate = m)
p
# Out:
# [1] 1.409775

# %% [markdown]
# - b. Histogram dari Distribusi Exponensial untuk 10, 100, 1000 dan 10000 bilangan random

# %%
hist(rexp(10, rate = m))
# Out:
# Plot with title "Histogram of rexp(10, rate = m)"

# %%
hist(rexp(100, rate = m))
# Out:
# Plot with title "Histogram of rexp(100, rate = m)"

# %%
hist(rexp(1000, rate = m))
# Out:
# Plot with title "Histogram of rexp(1000, rate = m)"

# %%
hist(rexp(10000, rate = m))
# Out:
# Plot with title "Histogram of rexp(10000, rate = m)"

# %% [markdown]
# - c. Nilai Rataan (μ) dan Varian (σ²) dari Distribusi Exponensial untuk n = 100 dan λ = 3

# %%
rataan <- 1 / m
varian <- 1 / (m ^2)

cat("rataan: ", rataan, "\n")
cat("varian: ", varian, "\n")
# Out:
# rataan:  0.3333333
# varian:  0.1111111
